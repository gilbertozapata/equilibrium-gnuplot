# %%
reset
unset key
set xrange [0:0.2]
set yrange [0:1000]
set sample 100000
plot 269

# %%
replot (25*4*x**2)/(0.2-x)/(0.5-3*x)**3

# %%
set yrange [260:280]
replot (25*4*x**2)/(0.2-x)/(0.5-3*x)**3

# %%
set xrange [0.078:0.079]
replot (25*4*x**2)/(0.2-x)/(0.5-3*x)**3
